# %%
import inspectus
import numpy as np

loss = np.array([[1/x**2 + var/5 for var in np.random.rand(100)] for x in np.linspace(1, 5, num=100)])

table = inspectus.data_to_table(loss)

inspectus.render(table, width=800, height=400, height_minimap=100, levels=5)
# Out:
# alt.VConcatChart(...)
