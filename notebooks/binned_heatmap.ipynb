# %%
import inspectus

# %%
from inspectus.binned_heatmap_viz import data_to_table

# %%
import numpy as np

arr = np.random.rand(1000)/2
x_data = np.array([x%10 for x in range(1000)])
table = data_to_table(arr, x_data)

# %%
arr2 = np.random.rand(1000)
x_data2 = np.array([x%10 for x in range(1000)])
table2 = data_to_table(arr2, x_data2)

# %%
from inspectus.binned_heatmap_viz import render

render([table], names=['test 1'], x_name="x", width=500, height=500, height_minimap=100)
# Out:
# alt.VConcatChart(...)
